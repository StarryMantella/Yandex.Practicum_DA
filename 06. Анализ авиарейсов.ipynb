# %% [markdown]
# <hr style="border: 2px solid green;" />
#
# ## Комментарий ревьювера
#
# Батор, привет!
#
# 🤚Меня зовут, Олег Юрьев, я буду проверять твой проект. Если не против, я буду обращаться к тебе на _ТЫ_ . Если это неприемлемо, обязательно напиши мне в комментариях - мы перейдем на _ВЫ_ .
#
# 🤝Спасибо, что сдал проект вовремя. Тобой проделана большая работа, молодец!
#
# ✏️В этой тетрадке ты найдешь мои комментарии.
#
# Комментарии будут выделены:
#
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
#     Безупречная работа</div>
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid orange 2px; padding: 20px"> <b>Что можно улучшить</b><br>
#     Ничего дорабатывать не надо, данные пункты работают нормально, но есть способы улучшить. Несколько таких комментариев допустимы, но более - придется некоторые доработать. Большое кол-во мелких замечаний и помарок сказываются на общем впечатлении от работы.</div>
# <br>
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid red 2px; padding: 20px"> <b>Что необходимо доработать</b><br>
#     Такие пункты необходимо исправить в первую очередь, чтобы я смог принять проект.</div>
#
# Не удаляй комментарии, так будем следить за динамикой 📈
#
# Давай будем в диалоге - основные цели в диалоге:
# - обмен опытом (да я тоже учусь у студентов👨‍🎓)
# - выполнить проект еще лучше
# - помочь тебе стать аналитиком
#
# Поэтому чтобы мне проще было проверять повторно, а тебе контролировать процесс ревью, оставляй свои комментарии и выделяй их.
#
# <div class="alert alert-info" style="border:solid blue 2px; padding: 20px"> <b>Комментарий студента:</b> Например, вот так.</div>
#
# Поехали! :)
#
# <hr style="border: 2px solid green;" />

# %% [markdown]
# **Импорт библиотек:**

# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# **Импорт файлов, их просмотр и изучение общей информации о них:**

# %%
query_1 = pd.read_csv('/datasets/query_1.csv')
query_3 = pd.read_csv('/datasets/query_3.csv')

# %%
display(query_1)
query_1.info()
# Out:
#                  model  flights_amount
# 0      Airbus A319-100             607
# 1      Airbus A321-200             960
# 2       Boeing 737-300             630
# 3       Boeing 767-300             600
# 4       Boeing 777-300             300
# 5   Bombardier CRJ-200            4446
# 6   Cessna 208 Caravan            4557
# 7  Sukhoi SuperJet-100            4185
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
# model             8 non-null object
# flights_amount    8 non-null int64
# dtypes: int64(1), object(1)
# memory usage: 256.0+ bytes

# %%
display(query_3)
query_3.info()
# Out:
#                city  average_flights
# 0            Абакан         3.870968
# 1           Анадырь         1.000000
# 2             Анапа         2.161290
# 3       Архангельск         5.354839
# 4         Астрахань         2.451613
# ..              ...              ...
# 96             Чита         1.580645
# 97           Элиста         4.870968
# 98   Южно-Сахалинск         4.290323
# 99           Якутск         2.741935
# 100       Ярославль         1.322581
#
# [101 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 2 columns):
# city               101 non-null object
# average_flights    101 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# **В таблице Query_3 округлим числа в столбце average_flights до 2-х знаков после запятой, и изменим на тип 'float':**

# %%
query_3['average_flights'] = round(query_3['average_flights'], 2)
query_3['average_flights'] = query_3['average_flights'].astype('float')
print(query_3)
query_3.info()
# Out:
#                city  average_flights
# 0            Абакан             3.87
# 1           Анадырь             1.00
# 2             Анапа             2.16
# 3       Архангельск             5.35
# 4         Астрахань             2.45
# ..              ...              ...
# 96             Чита             1.58
# 97           Элиста             4.87
# 98   Южно-Сахалинск             4.29
# 99           Якутск             2.74
# 100       Ярославль             1.32
#
# [101 rows x 2 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 2 columns):
# city               101 non-null object
# average_flights    101 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 1.7+ KB

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Супер, обзор данных выполнен отлично!</div> <br>

# %% [markdown]
# **Выберем топ-10 городов по количеству рейсов:**

# %%
top_10 = query_3.sort_values(by='average_flights', ascending=False).head(10)
top_10
# Out:
#                city  average_flights
# 43           Москва           129.77
# 70  Санкт-Петербург            31.16
# 54      Новосибирск            17.32
# 33       Красноярск            11.58
# 20     Екатеринбург            11.32
# 67   Ростов-на-Дону            10.19
# 63            Пермь            10.13
# 10           Брянск            10.00
# 74             Сочи             9.61
# 84        Ульяновск             9.58

# %% [markdown]
# **ПОСТРОИМ ГРАФИКИ:**

# %% [markdown]
# **1. Модели самолетов и количество рейсов:**

# %%
sns.barplot(x='model', y='flights_amount', data=query_1.sort_values(by='flights_amount'))
plt.title("Количество рейсов по моделям самолетов")
plt.ylabel("Кол-во рейсов")
plt.xlabel("Модель самолета")
sns.set(font_scale = 2)
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = (5,20)

# %% [markdown]
# **ВЫВОД:**
#
# Для начала возьмем данные о вместимости самолетов из Википедии:<br>
#
# Sukhoi SuperJet-100 - 103 места<br>
# Cessna 208 Caravan - 14 мест<br>
# Bombardier CRJ-200 - 40-50 мест<br>
# Boeing 777-300 - 550 мест<br>
# Boeing 767-300 - 375 мест<br>
# Boeing 737-300 - 149 мест<br>
# Airbus A321-200 - 180 мест<br>
# Airbus A319-100 - 116 места<br>
#
#    Можно сделать вывод, что больше всего рейсов совершается на небольших самолетах - Sukhoi, Cessna, Bombardier. Количество рейсов на этих моделях в несколько раз больше, чем на более вместительных Boeing и Airbus. Связано это скорее всего с тем, что внутри страны при междугородних перелетах Boeing и Airbus просто не будут полностью заполняться. Большое количество рейсов на Суперджетах обуславливается лоббированием отечественного производителя, и как следствие, самый большой парк суперджетов у Аэрофлота.

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>Отличная работа</b><br>
# Супер, отличные предположения👍</div> <br>

# %% [markdown]
# **Количество рейсов в зависимости от города:**

# %%
sns.barplot(x='city', y='average_flights', data=query_3.sort_values(by='average_flights', ascending=False))
plt.title("Количество рейсов в зависимости от города")
plt.ylabel("Количество рейсов")
plt.xlabel("")
sns.set(font_scale = 2)
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = (9, 6)

# %% [markdown]
# <div style="border-radius: 15px; box-shadow: 4px 4px 4px; border: solid green 2px; padding: 20px"> <b>Комментарий</b><br>Поменял местами ширину и длину фигуры, чтобы отображалось корректно</div>

# %% [markdown]
# **Топ-10 городов по количеству рейсов:**

# %%
sns.barplot(x='city', y='average_flights', data=top_10.sort_values(by='average_flights', ascending=False))
plt.title("Топ-10 городов по количеству рейсов")
plt.ylabel("Количество рейсов")
plt.xlabel("")
sns.set(font_scale = 2)
plt.xticks(rotation=90)
plt.rcParams["figure.figsize"] = (9,6)

# %% [markdown]
# **ВЫВОД по городам:**
#
# Ожидаемо, что лидером по количеству рейсов оказалась Москва - она в 4 с лишним раза опережает Санкт-Петербург, своего ближайшего преследователя.<br>
# В топ-5 также вошли Новосибирск, Красноярск и Екатеринбург. У остальных же городов в топ-10 не более 10 рейсов, у остаьльных городов - в среднем не более 5.

# %% [markdown]
# <img src=https://www.meme-arsenal.com/memes/5f0ccdd82eda80ded9db721a8746f804.jpg><br>
# <hr style="border: 10px solid green;" />
#
# ## <span style="color:green">Финальный комментарий<span>
# Спасибо за проделанную работу🤝
#
# Батор, работа выполнена отлично!
#
# Данный проект не такой объемный как другие - как минимум это передышка<br>
# Так же весь проект состоит из 3-х частей:<br>
# <ul>
#     <li> - парсер
#     <li> - sql
#     <li> - аналитика средствами python</ul><br>
# И так вышло, что часть про python дает практику визуализации данных - это важная составляющая работы аналитика. Не всегда можно обойтись таблицами, как говорится, лучше один раз увидеть. В моей работе часто приходится визуализировать данные (мой любимый инструмент <a href="https://habr.com/ru/post/502958/">Шпаргалка по plotly</a>, <a href="https://plotly.com/python/">Plotly Docs</a>) - иногда даже очень примитивные таблицы (размером 2х3) при визуализации сильнее убеждают заказчика или описывают проблему без лишних вопросов. <br>
# Данный проект, можно рассматривать:<br>
# <ul>
#     <li> как практику визуализации - например, глубже изучить <code>matplotlib</code>
#     <li> понять основы визуализации (выбор типа графика, правильное расположение данных)
#     <li> изучить новый инструмент визуализации (plotly, bokeh, seaborn,  altair и др), может быть изучить новое представление таблиц в pandas <a href="https://pandas.pydata.org/pandas-docs/stable/user_guide/style.html">стилизация</a>
#     <li> придумать еще задачи для проекта, например, используя парсинг, получить данные о населении городов и проверить гипотезу - есть ли связь между кол-вом рейсов и населением</ul><br>
#
# Поздравляю, проект принят👍
